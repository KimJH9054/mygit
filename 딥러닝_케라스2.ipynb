# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJH9054/mygit/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%BC%80%EB%9D%BC%EC%8A%A42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %%
(train_input, train_target),(test_input, test_target)=keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
test_input.shape
# Out:
# (10000, 28, 28)

# %%
import matplotlib.pyplot as plt

fig, axs =plt.subplots(1,10, figsize=(10,10))
for i in range(10):
  axs[i].imshow(train_input[i])
plt.show()

# %%
[train_target[i] for i in range(10)]
# Out:
# [np.uint8(9),
#  np.uint8(0),
#  np.uint8(0),
#  np.uint8(3),
#  np.uint8(0),
#  np.uint8(2),
#  np.uint8(7),
#  np.uint8(2),
#  np.uint8(5),
#  np.uint8(5)]

# %%
train_scaled=train_input/255.0

# %%
train_scaled=train_scaled.reshape(-1,28*28)

# %%
train_scaled.shape
# Out:
# (60000, 784)

# %%
from sklearn.model_selection import train_test_split
train_scaled, val_scaled, train_target, val_target =train_test_split(train_scaled,train_target,test_size=0.2, random_state=42)

# %%
train_target.shape
# Out:
# (48000,)

# %%
dense=keras.layers.Dense(10, activation='softmax', input(784,) )
# Out:
#   File "<ipython-input-20-84350e068891>", line 1
#     dense=keras.layers.Dense(10, activation='softmax', input(784,) )
#                                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
model=keras.Sequential(dense)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-df04a79ff085> in <cell line: 0>()
# ----> 1 model=keras.Sequential(dense)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      72         self._layers = []
#      73         if layers:
# ---> 74             for layer in layers:
#      75                 self.add(layer, rebuild=False)
#      76             self._maybe_rebuild()
#
# TypeError: 'Dense' object is not iterable
